# %%
import numpy as np
from skimage import io
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import glob

# %% [markdown]
# # D1

# %%
folder_single = '/media/DATA/jbonato/astro_segm/set1/train_single/'

# %%
def create_grid_plot(items,ncol,nrow):
    num = ncol*nrow
    sample = np.random.choice(len(items), num,replace=False)

    plt.figure(figsize = (10,10))
    gs1 = gridspec.GridSpec(nrow, ncol)
    gs1.update(wspace=0.0, hspace=0.05) # set the spacing between axes. 

    for i in range(num):
        im = io.imread(items[sample[i]])
       # i = i + 1 # grid spec indexes from 0
        print(im.shape)
        ax1 = plt.subplot(gs1[i])
        plt.axis('off')
        ax1.set_aspect('equal')
        ax1.imshow(im)
        
images_l = glob.glob(folder_single+'*.tif')
images_l_filt = [i for i in images_l if not('nf_enh' in i)]
images_l_nfilt= [i for i in images_l if 'nf_enh' in i]
create_grid_plot(images_l,2,2)
# images_l_filt
# Out:
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)

# %%
create_grid_plot(images_l_nfilt,2,2)
# Out:
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)

# %% [markdown]
# # D2

# %%
folder_single = '/media/DATA/jbonato/astro_segm/set2/train_single/'

# %%
images_l = glob.glob(folder_single+'*.tif')
images_l_filt = [i for i in images_l if not('nf_enh' in i)]
images_l_nfilt= [i for i in images_l if 'nf_enh' in i]
create_grid_plot(images_l,2,2)
# Out:
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)

# %%
create_grid_plot(images_l_nfilt,2,2)
# Out:
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)

# %% [markdown]
# # D3

# %%
folder_single = '/media/DATA/jbonato/astro_segm/set3/train_single/'
images_l = glob.glob(folder_single+'*.tif')
images_l_filt = [i for i in images_l if not('nf_enh' in i)]
images_l_nfilt= [i for i in images_l if 'nf_enh' in i]
create_grid_plot(images_l_filt,2,2)
# Out:
# (48, 48)
# (48, 48)
# (48, 48)
# (48, 48)

# %%
create_grid_plot(images_l_nfilt,2,2)
# Out:
# (48, 48)
# (48, 48)
# (48, 48)
# (48, 48)
