# %% [markdown]
# # Training Phase Pre-Processing
# In this notebook there is a guide for the pre-processing step in the trainig phase.
# ### Information
# The role of the functions in the code is described briefly in code comments

# %%
import numpy as np
import os
from skimage import io
import sys
import h5py
import glob
from skimage import io
import matplotlib.pyplot as plt
import pickle

#### MODULES used in the code
sys.path.insert(0,'/media/DATA/jbonato/astro_segm/Astro3S/modules/')
#from img_Sp_Sharp import create_img
from mask_roi_from_fiji import create_mask
from gen_single_astro import save_im, spatial_pp

#SET IMAGES DIM
N = 512
M = 512

# %%
set_dir='/media/DATA/jbonato/astro_segm/set4/'
folder_to_save = '/media/DATA/jbonato/astro_segm/set4/dataset/'
folder_single = '/media/DATA/jbonato/astro_segm/set4/train_single/'
mask_path_root = '/media/DATA/jbonato/astro_segm/zip_mask/consensus/D4/'

if not(os.path.exists(folder_to_save)):
    os.mkdir(folder_to_save)
    print('Created',folder_to_save)

if not(os.path.exists(folder_single)):
    os.mkdir(folder_single)
    print('Created',folder_single)


prefix='SMALL_'
folder_to_save+= prefix
folder_single+=prefix

##### LOAD PARAM DICT
with open(set_dir+'.tmp/dict_dataset1.txt', "rb") as fp:   #Pickling
    dict_param = pickle.load(fp)
dict_param
# Out:
# {'list': [0, 30, 60, 90, 120, 150, 180, 210, 240, 270, 300, 330, 360],
#  'blocks': 15,
#  'threads': 20,
#  'BPM_ratio': 2,
#  'bb': 48,
#  'N_pix_st': 25,
#  'astr_min': 22,
#  'percentile': 80,
#  'pad': 0,
#  'astro_num': 95,
#  'init_th': 0.5,
#  'decr_dim': 3,
#  'decr_th': 12,
#  'corr_int': True,
#  'gpu_flag': True,
#  'max_min': array([258,  40]),
#  'th1_p': 0.25,
#  'th2_p': 0.1}

# %%
remove_flag = False  # set true if you want to remove all
if remove_flag:
    for fl in glob.glob(folder_to_save+'*.hdf5'):
        os.remove(fl)
    for fl in glob.glob(folder_to_save+'*.tif'):
        os.remove(fl)
    for fl in glob.glob(folder_single+'*'):
        os.remove(fl)

items = os.listdir(set_dir)#collect folder

list_remotion = ['20','dataset','.ipynb_checkpoints','train_single','.tmp'] #insert the folder name to remove them
for rem in list_remotion:
    try:
        items.remove(rem)
    except:
        print('folder not removed because it is not present')
# Out:
# folder not removed because it is not present

# %%
items
# Out:
# ['1', '3', '7', '2', '5', '6', '8', '4']

# %%
im_enh_l=[]
th1_p = dict_param['th1_p']
th2_p = dict_param['th2_p']
for item in items[:1]:
    dataset_dir = os.path.join(set_dir,item)
    try:
        int(item)
        flag_go=True
    except Exception as ex:
        flag_go=False
        pass   
    if os.path.isdir(dataset_dir) and flag_go and int(item)<26:
        
        
        if len(item)==1:
            zer='00'
        else:
            zer='0'

       
        os.chdir(dataset_dir)
        image_ids = glob.glob('*')
        
        ######################################Mask#################################################
        mask_path = mask_path_root+'FOV_'+zer+item +'.zip'
        print('mask num: ',zer+item,' in ',mask_path)

        c_mask = create_mask(mask_path)###mask generation from .zip file generated using fiji
        instances_num = c_mask.get_dim()

        mask = np.empty((N, M, instances_num))
        soma_num, mask = c_mask.create_multiple_mask_im(im_dim=512)#im_dim=None add this attribute 
        #if N,M are different from 256

        values_soma = np.zeros((N,M),dtype = np.float32 )

        values_soma = np.sum(mask[:,:,:soma_num],axis=2)
        values = np.sum(mask[:,:,soma_num:],axis=2)
        values[values>1]=1
        values = values.astype(np.float32) 
        values_soma = values_soma.astype(np.float32)
        ####eventual intersections between soma and processes are not treated here
        ###########################################################################################
        
        for image_id in image_ids:
            path_to_file = os.path.join(dataset_dir,image_id)
            if not(os.path.isdir(path_to_file)):

                print('Processing: ','FOV',item,' ',image_id)
                print(10*'*')

                file_path = os.path.join(dataset_dir, image_id)

                # Generate spatial sharpened map
                sp_pp = spatial_pp(file_path)
                stack,im_enh = sp_pp.create_img_d4() #see gen_single_astro.py for different spatial pp
                
                #appen to a list for visualization purposes
                im_enh_l.append(im_enh)
                
                #save unfiltered mask
                with h5py.File(folder_to_save +zer+item+'_nf.hdf5','w') as f:
                    dset = f.create_dataset('Values',data=values)
                    dset2 = f.create_dataset('Values_soma',data=values_soma)
                #SINGLE CELL CREATION
                #in this module are performed BBs extraction and Local activity filtering. Single cell images
                #are than saved into folder_single 
                # BBs dimension and 0 padding can be choosen as input of this function    
                values,values_soma =  save_im(im=im_enh,stack=stack,mask_soma=values_soma,mask_proc=values,\
                                              save_folder = folder_single+zer+item,item=int(item),\
                                              BB_dim=48,th1_p=th1_p,th2_p=th2_p,pad=0)
# Out:
# mask num:  001  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D4/FOV_001.zip
# Processing:  FOV 1   TSeries-06282021-1014-791_Ch1__movie_corrected.tiff
# **********

# %% [markdown]
# ### Adding new PP
#
# Here we write an example of how to add new spatial pp function creating a new class

# %%
see = False # see how to add new spatial preprocessing
class new_spatial_pp(spatial_pp):
    def __init__(self,file_path):
        super().__init__(file_path)
    def new_PP(self): ### this is a fake example
        '''this module return the recording and a spatial sharpened map'''
        return self.stack,np.median(self.stack,axis=0)
if see:
    n_sp_pp = new_spatial_pp(file_path)
    _,b = n_sp_pp.new_PP()
    plt.imshow(b)

# %% [markdown]
# # PLOT
# Here entire FOVs and single cell images can be plotted

# %%
import matplotlib.gridspec as gridspec
#Number of samples to plot
def create_grid_plot_l(items,ncol,nrow):
    num = ncol*nrow
    sample = np.random.choice(len(items), num,replace=False)
    
    plt.figure(figsize = (10,10))
    gs1 = gridspec.GridSpec(nrow, ncol)
    gs1.update(wspace=0.025, hspace=0.05) # set the spacing between axes. 

    for i in range(num):
       # i = i + 1 # grid spec indexes from 0
        ax1 = plt.subplot(gs1[i])
        plt.axis('off')
        ax1.set_aspect('equal')
        ax1.imshow(items[sample[i]])

# %%
create_grid_plot_l(im_enh_l,1,1)

# %%
def create_grid_plot(items,ncol,nrow):
    np.random.seed(20)
    num = ncol*nrow
    sample = np.random.choice(len(items), num,replace=False)
    print(sample)
    plt.figure(figsize = (10,10))
    gs1 = gridspec.GridSpec(nrow, ncol)
    gs1.update(wspace=0.0, hspace=0.05) # set the spacing between axes. 

    for i in range(num):
        im = io.imread(items[sample[i]])
       # i = i + 1 # grid spec indexes from 0
        ax1 = plt.subplot(gs1[i])
        plt.axis('off')
        ax1.set_aspect('equal')
        ax1.imshow(im)
        
images_l = glob.glob(folder_single+'*.tif')
images_l.sort()
images_l_filt = [i for i in images_l if not('nf_enh' in i)]


images_l_nfilt= [i for i in images_l if 'nf_enh' in i]


create_grid_plot(images_l_nfilt,5,5)
# Out:
# [23 38 44 49 33 39  0 54 42  5 53 12 76 27 21  2 70 59  8 37  4 31 73 74
#  75]

# %%
create_grid_plot(images_l_filt,5,5)
# Out:
# [23 38 44 49 33 39  0 54 42  5 53 12 76 27 21  2 70 59  8 37  4 31 73 74
#  75]

# %%
images_l
# Out:
# ['/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_0.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_0nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_1.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_10.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_10nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_11.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_11nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_12.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_12nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_13.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_13nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_14.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_14nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_15.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_15nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_16.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_16nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_17.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_17nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_18.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_18nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_19.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_19nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_1nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_2.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_20.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_20nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_21.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_21nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_22.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_22nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_23.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_23nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_24.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_24nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_25.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_25nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_26.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_26nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_27.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_27nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_28.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_28nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_29.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_29nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_2nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_3.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_30.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_30nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_31.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_31nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_32.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_32nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_33.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_33nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_34.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_34nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_35.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_35nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_36.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_36nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_37.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_37nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_38.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_38nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_39.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_39nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_3nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_4.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_40.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_40nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_41.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_41nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_42.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_42nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_43.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_43nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_44.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_44nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_45.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_45nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_46.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_46nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_47.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_47nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_48.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_48nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_49.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_49nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_4nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_5.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_50.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_50nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_51.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_51nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_52.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_52nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_53.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_53nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_54.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_54nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_55.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_55nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_56.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_56nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_57.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_57nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_58.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_58nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_59.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_59nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_5nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_6.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_60.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_60nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_61.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_61nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_62.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_62nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_63.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_63nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_64.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_64nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_65.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_65nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_66.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_66nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_67.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_67nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_68.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_68nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_69.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_69nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_6nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_7.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_70.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_70nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_71.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_71nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_72.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_72nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_73.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_73nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_74.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_74nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_75.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_75nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_76.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_76nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_77.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_77nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_7nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_8.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_8nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_9.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_9nf_enh.tif']

# %%
images_l_nfilt
# Out:
# ['/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_0nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_10nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_11nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_12nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_13nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_14nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_15nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_16nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_17nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_18nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_19nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_1nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_20nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_21nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_22nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_23nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_24nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_25nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_26nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_27nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_28nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_29nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_2nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_30nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_31nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_32nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_33nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_34nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_35nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_36nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_37nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_38nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_39nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_3nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_40nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_41nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_42nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_43nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_44nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_45nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_46nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_47nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_48nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_49nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_4nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_50nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_51nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_52nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_53nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_54nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_55nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_56nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_57nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_58nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_59nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_5nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_60nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_61nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_62nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_63nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_64nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_65nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_66nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_67nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_68nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_69nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_6nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_70nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_71nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_72nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_73nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_74nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_75nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_76nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_77nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_7nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_8nf_enh.tif',
#  '/media/DATA/jbonato/astro_segm/set4/train_single/SMALL_001_single_9nf_enh.tif']
