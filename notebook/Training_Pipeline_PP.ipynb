# %% [markdown]
# # Training Phase Pre-Processing
# In this notebook there is a guide for the pre-processing step in the trainig phase.
# ### Information
# The role of the functions in the code is described briefly in code comments

# %%
root_folder = '/media/DATA/jbonato/astro_segm'

# %%
import numpy as np
import os
from skimage import io
import sys
import h5py
import glob
from skimage import io
import matplotlib.pyplot as plt
import pickle

#### MODULES used in the code
sys.path.insert(0,root_folder+'/RASTA/modules/')
#from img_Sp_Sharp import create_img
from mask_roi_from_fiji import create_mask
from gen_single_astro import save_im, spatial_pp

#SET IMAGES DIM
N = 256 
M = 256

# %%
set_dir=root_folder+'/set1/'
folder_to_save = root_folder+'/set1/dataset/'
folder_single = root_folder+'/set1/train_single/'
mask_path_root = root_folder+'/zip_mask/consensus/D1/'

if not(os.path.exists(folder_to_save)):
    os.mkdir(folder_to_save)
    print('Created',folder_to_save)

if not(os.path.exists(folder_single)):
    os.mkdir(folder_single)
    print('Created',fodler_single)


prefix='SMALL_'
folder_to_save+= prefix
folder_single+=prefix

##### LOAD PARAM DICT
with open(set_dir+'.tmp/dict_dataset1.txt', "rb") as fp:   #Pickling
    dict_param = pickle.load(fp)
dict_param
# Out:
# {'list': [0, 40, 80, 120, 160],
#  'blocks': 15,
#  'threads': 32,
#  'BPM_ratio': 3,
#  'bb': 96,
#  'N_pix_st': 100,
#  'astr_min': 80,
#  'percentile': 80,
#  'pad': 5,
#  'astro_num': 4,
#  'init_th_': 0.6,
#  'decr_dim': 10,
#  'decr_th': 25,
#  'corr_int': False,
#  'gpu_flag': True,
#  'max_min': array([345,  89]),
#  'th1_p': 0.25,
#  'th2_p': 0.1}

# %%
remove_flag = False  # set true if you want to remove all
if remove_flag:
    for fl in glob.glob(folder_to_save+'*.hdf5'):
        os.remove(fl)
    for fl in glob.glob(folder_to_save+'*.tif'):
        os.remove(fl)
    for fl in glob.glob(folder_single+'*'):
        os.remove(fl)

items = os.listdir(set_dir)#collect folder

list_remotion = ['20'] #insert the folder name to remove them
for rem in list_remotion:
    try:
        items.remove(rem)
    except:
        print('folder not removed because it is not present')
# Out:
# folder not removed because it is not present

# %%
im_enh_l=[]
th1_p = dict_param['th1_p']
th2_p = dict_param['th2_p']
for item in items:
    dataset_dir = os.path.join(set_dir,item)
    try:
        int(item)
        flag_go=True
    except Exception as ex:
        flag_go=False
        pass   
    if os.path.isdir(dataset_dir) and flag_go and int(item)<26:
        
        
        if len(item)==1:
            zer='00'
        else:
            zer='0'

       
        os.chdir(dataset_dir)
        image_ids = glob.glob('*')
        
        ######################################Mask#################################################
        mask_path = mask_path_root+'RoiSet_SMALL_'+zer+item +'.zip'
        print('mask num: ',zer+item,' in ',mask_path)

        c_mask = create_mask(mask_path)###mask generation from .zip file generated using fiji
        instances_num = c_mask.get_dim()

        mask = np.empty((N, M, instances_num))
        soma_num, mask = c_mask.create_multiple_mask_im()#im_dim=None add this attribute 
        #if N,M are different from 256

        values_soma = np.zeros((N,M),dtype = np.float32 )

        values_soma = np.sum(mask[:,:,:soma_num],axis=2)
        values = np.sum(mask[:,:,soma_num:],axis=2)
        values[values>1]=1
        values = values.astype(np.float32) 
        values_soma = values_soma.astype(np.float32)
        ####eventual intersections between soma and processes are not treated here
        ###########################################################################################
        
        for image_id in image_ids:
            path_to_file = os.path.join(dataset_dir,image_id)
            if not(os.path.isdir(path_to_file)):

                print('Processing: ','SMALL',item,' ',image_id)
                print(10*'*')

                file_path = os.path.join(dataset_dir, image_id)

                # Generate spatial sharpened map
                sp_pp = spatial_pp(file_path)
                stack,im_enh = sp_pp.create_img() #see gen_single_astro.py for different spatial pp
                
                #appen to a list for visualization purposes
                im_enh_l.append(im_enh)
                
                #save unfiltered mask
                with h5py.File(folder_to_save +zer+item+'_nf.hdf5','w') as f:
                    dset = f.create_dataset('Values',data=values)
                    dset2 = f.create_dataset('Values_soma',data=values_soma)
                #SINGLE CELL CREATION
                #in this module are performed BBs extraction and Local activity filtering. Single cell images
                #are than saved into folder_single 
                # BBs dimension and 0 padding can be choosen as input of this function    
                values,values_soma =  save_im(im=im_enh,stack=stack,mask_soma=values_soma,mask_proc=values,\
                                              save_folder = folder_single+zer+item,item=int(item),\
                                              BB_dim=86,th1_p=th1_p,th2_p=th2_p)
# Out:
# mask num:  022  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_022.zip
# Processing:  SMALL 22   TSeries-09042017-1020-551_Cycle00001_Ch2_0000movieNoRM4Iteration.tif
# **********
# file loading...
# mask num:  013  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_013.zip
# Processing:  SMALL 13   TSeries-04172019-1817-1288_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  024  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_024.zip
# Processing:  SMALL 24   TSeries-09052017-1126-564_Cycle00001_Ch2_0000movieNoRM4Iteration.tif
# **********
# file loading...
# mask num:  001  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_001.zip
# Processing:  SMALL 1   TSeries-04082019-1513-1250_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  011  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_011.zip
# Processing:  SMALL 11   TSeries-04172019-1817-1282_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  003  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_003.zip
# Processing:  SMALL 3   TSeries-04082019-1513-1252_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  015  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_015.zip
# Processing:  SMALL 15   TSeries-04182019-1453-1295_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  023  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_023.zip
# Processing:  SMALL 23   TSeries-09052017-1126-559_Cycle00001_Ch2_0000movieNoRM4Iteration.tif
# **********
# file loading...
# mask num:  007  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_007.zip
# Processing:  SMALL 7   TSeries-04112019-1605-1267_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  002  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_002.zip
# Processing:  SMALL 2   TSeries-04082019-1513-1251_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  005  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_005.zip
# Processing:  SMALL 5   TSeries-04112019-1605-1258_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  012  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_012.zip
# Processing:  SMALL 12   TSeries-04172019-1817-1287_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  017  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_017.zip
# Processing:  SMALL 17   TSeries-07192018-1913-1119_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  009  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_009.zip
# Processing:  SMALL 9   TSeries-04172019-1817-1280_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  021  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_021.zip
# Processing:  SMALL 21   TSeries-09042017-1020-547_Cycle00001_Ch2_0000movieNoRM4Iteration.tif
# **********
# file loading...
# mask num:  006  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_006.zip
# Processing:  SMALL 6   TSeries-04112019-1605-1266_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  010  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_010.zip
# Processing:  SMALL 10   TSeries-04172019-1817-1281_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  014  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_014.zip
# Processing:  SMALL 14   TSeries-04172019-1817-1289_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  016  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_016.zip
# Processing:  SMALL 16   TSeries-06072018-1654-1094_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  025  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_025.zip
# Processing:  SMALL 25   TSeries-09052017-1126-572_Cycle00001_Ch2_0000movie_momovieNoRM4Iteration.tif
# **********
# file loading...
# mask num:  018  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_018.zip
# Processing:  SMALL 18   TSeries-07262018-1151-1126_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  008  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_008.zip
# Processing:  SMALL 8   TSeries-04112019-1605-1268_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  019  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_019.zip
# Processing:  SMALL 19   TSeries-07262018-1151-1129_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...
# mask num:  004  in  /media/DATA/jbonato/astro_segm/zip_mask/consensus/D1/RoiSet_SMALL_004.zip
# Processing:  SMALL 4   TSeries-04112019-1605-1257_Ch2__movie_corrected_aligned.tiff
# **********
# file loading...

# %% [markdown]
# ### Adding new PP
#
# Here we write an example of how to add new spatial pp function creating a new class

# %%
see = False # see how to add new spatial preprocessing
class new_spatial_pp(spatial_pp):
    def __init__(self,file_path):
        super().__init__(file_path)
    def new_PP(self): ### this is a fake example
        '''this module return the recording and a spatial sharpened map'''
        return self.stack,np.median(self.stack,axis=0)
if see:
    n_sp_pp = new_spatial_pp(file_path)
    _,b = n_sp_pp.new_PP()
    plt.imshow(b)

# %% [markdown]
# # PLOT
# Here entire FOVs and single cell images can be plotted

# %%
import matplotlib.gridspec as gridspec
#Number of samples to plot
def create_grid_plot_l(items,ncol,nrow):
    num = ncol*nrow
    sample = np.random.choice(len(items), num,replace=False)
    
    plt.figure(figsize = (10,10))
    gs1 = gridspec.GridSpec(nrow, ncol)
    gs1.update(wspace=0.025, hspace=0.05) # set the spacing between axes. 

    for i in range(num):
       # i = i + 1 # grid spec indexes from 0
        ax1 = plt.subplot(gs1[i])
        plt.axis('off')
        ax1.set_aspect('equal')
        ax1.imshow(items[sample[i]])

# %%
create_grid_plot_l(im_enh_l,2,2)

# %%
def create_grid_plot(items,ncol,nrow):
    num = ncol*nrow
    sample = np.random.choice(len(items), num,replace=False)

    plt.figure(figsize = (10,10))
    gs1 = gridspec.GridSpec(nrow, ncol)
    gs1.update(wspace=0.0, hspace=0.05) # set the spacing between axes. 

    for i in range(num):
        im = io.imread(items[sample[i]])
       # i = i + 1 # grid spec indexes from 0
        ax1 = plt.subplot(gs1[i])
        plt.axis('off')
        ax1.set_aspect('equal')
        ax1.imshow(im)
        
images_l = glob.glob(folder_single+'*.tif')
images_l_filt = [i for i in images_l if not('nf_enh' in i)]
images_l_nfilt= [i for i in images_l if 'nf_enh' in i]
create_grid_plot(images_l_filt,5,5)
